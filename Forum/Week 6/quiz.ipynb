# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.svm import SVC
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Heart.csv", usecols = ['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol', 'Fbs', 'RestECG', 'MaxHR', 'ExAng', 'Oldpeak', 'Slope', 'Ca', 'Thal', 'AHD'])
df['Target'] = df['AHD']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Age        303 non-null    int64
#  1   Sex        303 non-null    int64
#  2   ChestPain  303 non-null    object
#  3   RestBP     303 non-null    int64
#  4   Chol       303 non-null    int64
#  5   Fbs        303 non-null    int64
#  6   RestECG    303 non-null    int64
#  7   MaxHR      303 non-null    int64
#  8   ExAng      303 non-null    int64
#  9   Oldpeak    303 non-null    float64
#  10  Slope      303 non-null    int64
#  11  Ca         299 non-null    float64
#  12  Thal       301 non-null    object
#  13  AHD        303 non-null    object
#  14  Target     303 non-null    object
# dtypes: float64(2), int64(9), object(4)
# memory usage: 35.6+ KB

# %%
df.iloc[0:5, 0:14]
# Out:
#    Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0   63    1       typical     145   233    1        2    150      0      2.3
# 1   67    1  asymptomatic     160   286    0        2    108      1      1.5
# 2   67    1  asymptomatic     120   229    0        2    129      1      2.6
# 3   37    1    nonanginal     130   250    0        0    187      0      3.5
# 4   41    0    nontypical     130   204    0        2    172      0      1.4
#
#    Slope   Ca        Thal  AHD
# 0      3  0.0       fixed   No
# 1      2  3.0      normal  Yes
# 2      2  2.0  reversable  Yes
# 3      3  0.0      normal   No
# 4      1  0.0      normal   No

# %%
df.iloc[298:303, 0:14]
# Out:
#      Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 298   45    1       typical     110   264    0        0    132      0
# 299   68    1  asymptomatic     144   193    1        0    141      0
# 300   57    1  asymptomatic     130   131    0        0    115      1
# 301   57    0    nontypical     130   236    0        2    174      0
# 302   38    1    nonanginal     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca        Thal  AHD
# 298      1.2      2  0.0  reversable  Yes
# 299      3.4      2  2.0  reversable  Yes
# 300      1.2      2  1.0  reversable  Yes
# 301      0.0      2  1.0      normal  Yes
# 302      0.0      1  NaN      normal   No

# %%
print(f"Mean : {df['MaxHR'].mean()}")
print(f"Count : {df['MaxHR'].count()}")
print(f"SD : {df['MaxHR'].std()}")
print(f"Min : {df['MaxHR'].min()}")
print(f"Max : {df['MaxHR'].max()}")
# Out:
# Mean : 149.6072607260726
# Count : 303
# SD : 22.875003276980376
# Min : 71
# Max : 202

# %%
df.isna().any()
print(df.isna().sum())
# Out:
# Age          0
# Sex          0
# ChestPain    0
# RestBP       0
# Chol         0
# Fbs          0
# RestECG      0
# MaxHR        0
# ExAng        0
# Oldpeak      0
# Slope        0
# Ca           4
# Thal         2
# AHD          0
# Target       0
# Mean         0
# dtype: int64

# %%
df['Age'] = df.merge(df['Age'].drop_duplicates())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 df['Age'] = df.merge(df['Age'].drop_duplicates())
#
# File c:\Users\ferdi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3646, in DataFrame.__setitem__(self, key, value)
#    3644     self._setitem_array(key, value)
#    3645 elif isinstance(value, DataFrame):
# -> 3646     self._set_item_frame_value(key, value)
#    3647 elif (
#    3648     is_list_like(value)
#    3649     and not self.columns.is_unique
#    3650     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3651 ):
#    3652     # Column to set is duplicated
#    3653     self._setitem_array([key], value)
#
# File c:\Users\ferdi\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3776, in DataFrame._set_item_frame_value(self, key, value)
# ...

# %%
df['Age_Range'] = np.where(df['Age'] > 55, "Elderly", df['Age'] < 40, "Young", "Middle Aged")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 df['Age_Range'] = np.where(df['Age'] > 55, "Elderly", df['Age'] < 40, "Young", "Middle Aged")
#
# File <__array_function__ internals>:4, in where(*args, **kwargs)
#
# TypeError: where() takes from 1 to 3 positional arguments but 5 were given
